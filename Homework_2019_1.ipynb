# %% [markdown]
# # Homework 1

# %% [raw]
# 1. Assume you have $2000 deposite in a bank, the annual interest rate is 5% from 2019 to 2024, and decrease to 3% from 2025 to 2029. How much is your $2000 worth at that time？ Write down your code in the cell below:

# %%
# Write down your code below
Future_Value = 2000*(1+0.05)**6*(1+0.03)**5
print("The future value of $2000 at 2029:", Future_Value)
# Out:
# The future value of $2000 at 2029: 3107.076266518026

# %% [raw]
# 2. Now use variables to rewrite the code above. (hint: use deposite = 2000 as variable)

# %%
# Write down your code below
def FV(deposit):
    FV = deposit*(1+0.05)**6*(1+0.03)**5
    return(FV)
print("The future value of $2000 at 2029:", FV(2000))
# Out:
# The future value of $2000 at 2029: 3107.076266518026

# %% [raw]
# 3. Calculate the sum of odd and sum of even number in 1-1000. Write down your code in the cell below:

# %%
# Write down your code below
print("The sum of odd number in 1-1000:", sum(list(range(1,1000,2))))
print("The sum of even number in 1-1000:", sum(list(range(2,1001,2))))
# Out:
# The sum of odd number in 1-1000: 250000
# The sum of even number in 1-1000: 250500

# %% [raw]
# 4. Now rewrite your code, this time once one of the sum of odd or even larger than 100, stop the program and output the result, also tell which one is larger than 100 first, sum of odd or sum of even. Write down your code in the cell below:

# %%
# Write down your code below
total_odd = 0
total_even = 0
for i in range(1,1001):
    if (i % 2 == 1):
        total_odd = total_odd + i
        if total_odd > 100 and total_even <= 100:
            print("Which one is larger than 100 first: the sum of odd number")
            break
    if (i % 2 == 0):
        total_even = total_even + i
        if total_even > 100 and total_odd <= 100:
            print("Which one is larger than 100 first: the sum of even number")
            break
print("The sum of odd number:" ,total_odd)
print("The sum of even number:" ,total_even)
# Out:
# Which one is larger than 100 first: the sum of even number
# The sum of odd number: 100
# The sum of even number: 110

# %% [raw]
# 5. There is a list of number [11, 22, 23, 54, 68, 79, 34, 46, 71], find out which one of them can be divided by 2, output the number and its index. (hint: index start from zero). Write down your code in the cell below:

# %%
# Write down your code below
a = [11, 22, 23, 54, 68, 79, 34, 46, 71]
number = [i for i in a if i % 2 == 0]
index = [a.index(x) for x in number]
print("The numbers:", number)
print("The index:", index)
# Out:
# The numbers: [22, 54, 68, 34, 46]
# The index: [1, 3, 4, 6, 7]

# %% [raw]
# 6. Define a function to find out the longest string of a string list. Write down your code in the cell below, part of code has been given:

# %%
# Write down your code below
def longest(strList): 
    longestStr = max(strList, key = len)
    return(longestStr)
strList = ['Hello', 'Simon', 'I', 'Love', 'Quantitative', 'Finance', 'with', 'Python']
longestStr = longest(strList)
print(longestStr)
# Out:
# Quantitative

# %% [raw]
# 7. Now use index to output part of the list above "ILoveQuantitativeFinance". Write down your code in the cell below:

# %%
# Write down your code below
strList = ['Hello', 'Simon', 'I', 'Love', 'Quantitative', 'Finance', 'with', 'Python']
strList[2]+strList[3]+strList[4]+strList[5]
# Out:
# 'ILoveQuantitativeFinance'

# %% [raw]
# 8. using the data array below, calculate the result of following problems:
#
#     a. sum of row 2 column 1 and row 1 column 1.
#
#     b. product of row 3 column 2 and row 2 column 3.
#
#     c. difference of row 1 column 2 and row 3 column 1.

# %%
# Write down your code below
data = [[1.2, 3.5, 5.6, 5.2], [2.2, 8.6, 6.5, 3.2], [2.0, 3.3, 9.2, 7.9]]
a = data[1][0] + data[0][0]
b = data[2][1] * data[1][2]
c = data[0][1] - data[2][0]
print(a)
print(b)
print(c)
# Out:
# 3.4000000000000004
# 21.45
# 1.5

# %% [raw]
# 9. There is a list of number, can you convert it to numpy array? And use numpy methods to find out the largest number, smallest number and their index. Write down your code in the cell below:

# %%
# Write down your code below
import numpy as np

data = [[1.2, -3.5, 5.6], [-2.2, 8.6, 6.5], [2.0, 3.3, -9.2], [4.5, 2.7, -6.6]]
data_arr = np.array(data)
print(data_arr)
print("The largest number and its index:", np.max(data_arr),",",np.where(data_arr == np.max(data_arr)))
print("The smallest number and its index:", np.min(data_arr),",",np.where(data_arr == np.min(data_arr)))
# Out:
# [[ 1.2 -3.5  5.6]
#  [-2.2  8.6  6.5]
#  [ 2.   3.3 -9.2]
#  [ 4.5  2.7 -6.6]]
# The largest number and its index: 8.6 , (array([1]), array([1]))
# The smallest number and its index: -9.2 , (array([2]), array([2]))

# %% [raw]
# 10. Now same array as above. Can you reshape it to a one dimension array and sort the number in it as descending? Then try to output those number greater than 0.

# %%
# Write down your code below
data = [[1.2, -3.5, 5.6], [-2.2, 8.6, 6.5], [2.0, 3.3, -9.2], [4.5, 2.7, -6.6]]
sorted_array = -np.sort(-data_arr.reshape(1,12))
print("Descending order:", sorted_array)
print("Number greater than 0:", sorted_array[sorted_array>0])
# Out:
# Descending order: [[ 8.6  6.5  5.6  4.5  3.3  2.7  2.   1.2 -2.2 -3.5 -6.6 -9.2]]
# Number greater than 0: [8.6 6.5 5.6 4.5 3.3 2.7 2.  1.2]

# %% [raw]
# 11. Can you convert and reshape those two list of numbers and use numpy to calculate the product of these two arrays?
# Write down your code in the cell below, (hint: make sure the dimensions when multiply operations, rows, columns.):

# %%
# Write down your code below
data1 = [[1.2, -3.5, 5.6], [-2.2, 8.6, 6.5], [2.0, 3.3, -9.2], [4.5, 2.7, -6.6]]
data2 = [[1.2, 3.5, 5.6, 5.2], [2.2, 8.6, 6.5, 3.2], [2.0, 3.3, 9.2, 7.9]]
data1_array = np.array(data1)
data2_array = np.array(data2)
product = np.dot(data1_array, data2_array)
print(product)
# Out:
# [[  4.94  -7.42  35.49  39.28]
#  [ 29.28  87.71 103.38  67.43]
#  [ -8.74   5.02 -51.99 -51.72]
#  [ -1.86  17.19 -17.97 -20.1 ]]

# %% [raw]
# 12. Try to use numpy to generate a single dimension normal distribution for 100 numbers and then plot the result of it, see what you can get. Then try to sort them, then make the visualization again.

# %%
# Write down your code below
import matplotlib.pyplot as plt

sample = np.random.normal(size = 100)
print(sample)
plt.plot(sample)

sort_sample = sorted(sample)
plt.plot(sort_sample)
# Out:
# [ 1.67016677  0.46873845 -0.27822765  1.61321248 -0.99872728 -1.92285372
#  -0.06700159 -0.65147779 -2.57724825  1.08760623  1.81059637 -0.20644379
#   0.59705905  0.46252757  0.74503072 -0.33464401 -0.39264942 -1.96347282
#  -0.44126545  1.08128386  1.1202089  -0.68626581 -1.43112468  0.77607584
#   0.51436931  2.67000099  0.56577538 -1.18086478  0.62172701 -0.55507926
#  -1.07452714 -0.8609956   0.30104159 -0.24086107 -1.28723478  0.23557051
#   0.3890227  -1.3932168  -0.1022853   2.81742231 -1.04732073  0.6633451
#   2.46023382 -1.8365455  -0.15122389  1.37851989  1.3081801  -0.22812275
#  -0.60666657  0.50686221 -0.93599248 -1.25993095 -0.63735707 -0.19281061
#   0.39616625 -0.53107592 -0.05354839  1.00826855  1.40732503  1.60012419
#  -0.52236813 -0.76741495  0.1211218   0.80369759 -0.60480237 -0.44575473
#   0.58804425 -0.08134932 -1.16461394 -1.40148928 -0.68180865 -0.9300428
#  -0.86820177  0.47341014 -0.79138225 -0.4961322   0.5798095   0.50955791
# ...

# %% [raw]
# 13. What about two dimenstion normal distribution? Can you finish the same step as above? Then what about three dimensions? Write down your code in the cell below.

# %%
from mpl_toolkits.mplot3d import Axes3D

def two_d_gaussian(x, y, mu, cov):
    # only if x and y are independent
    denom = 1/2 * 1/np.pi * 1/(np.sqrt(cov[0][0]) * np.sqrt(cov[1][1]))
    mole = np.exp(-1/2 * (np.power(x - mu[0], 2)/np.sqrt(cov[0][0]) + (np.power(y - mu[1], 2)/np.sqrt(cov[1][1]))))
    z = mole/denom
    return z

def plot_twoDGaussian():
    # Setting parameters
    mu = np.asarray([0.0, 0.0])
    sigma = np.asarray([[1.0, 0.0], [0.0, 1.0]])

    # Generating coordinates and gaussian distribution
    x = np.linspace(-1, 1, 100)
    y = np.linspace(-1, 1, 100)
    x, y = np.meshgrid(x, y)
    pos = np.empty(x.shape + (2,))
    pos[:, :, 0] = x
    pos[:, :, 1] = y
    z = two_d_gaussian(x, y, mu, sigma)

    # Plot the graph
    fig = plt.figure(figsize=(13, 7))
    ax = plt.axes(projection='3d')
    ax.plot_surface(x, y, z, rstride=1, cstride=1, cmap='rainbow', alpha=0.9)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.savefig("twoDGaussian.png")

plot_twoDGaussian()
